# %%
import pandas as pd

# %%
data=pd.read_csv("boston.csv")
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
data.head(5)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
data.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
data['CHAS'].value_counts()
# Out:
# CHAS
# 0    471
# 1     35
# Name: count, dtype: int64

# %%
# Handle the missing data

# %%
a=data.dropna(subset=['RM'])
a.shape
data.shape
# Out:
# (506, 14)

# %%
b=data.drop("RM",axis=1)
b.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX   AGE     DIS  RAD    TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  65.2  4.0900    1  296.0     15.3
# 1  0.02731   0.0   7.07     0  0.469  78.9  4.9671    2  242.0     17.8
# 2  0.02729   0.0   7.07     0  0.469  61.1  4.9671    2  242.0     17.8
# 3  0.03237   0.0   2.18     0  0.458  45.8  6.0622    3  222.0     18.7
# 4  0.06905   0.0   2.18     0  0.458  54.2  6.0622    3  222.0     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
meann=data['RM'].mean()
data['RM'].fillna(meann)
# Out:
# 0      6.575
# 1      6.421
# 2      7.185
# 3      6.998
# 4      7.147
#        ...
# 501    6.593
# 502    6.120
# 503    6.976
# 504    6.794
# 505    6.030
# Name: RM, Length: 506, dtype: float64

# %%
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(strategy='median')
imputer.fit(data)
# Out:
# SimpleImputer(strategy='median')

# %%
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(strategy='median')
imputer.fit(data)
# Out:
# SimpleImputer(strategy='median')

# %%
x=imputer.transform(data)
data=pd.DataFrame(x,columns=data.columns)
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
#   data visualization

# %%
import matplotlib.pyplot as plt
data.hist(bins=30,figsize=(16,14))
plt.show()

# %%
# correlations matrix
cor_data=data.corr()
cor_data['MEDV'].sort_values(ascending=False).head()
# cor_data.head()
# Out:
# MEDV    1.000000
# RM      0.695360
# ZN      0.360445
# B       0.333461
# DIS     0.249929
# Name: MEDV, dtype: float64

# %%
# visualization in scatter matrix
from pandas.plotting import scatter_matrix
attributes=["RM","LSTAT","ZN"]
scatter_matrix(data[attributes],figsize=(16,12))
plt.show()

# %%
data['TAXRM']=data['TAX']/data['RM']
data['TAXRM']
# Out:
# 0      45.019011
# 1      37.688834
# 2      33.681280
# 3      31.723350
# 4      31.061984
#          ...
# 501    41.407553
# 502    44.607843
# 503    39.134174
# 504    40.182514
# 505    45.273632
# Name: TAXRM, Length: 506, dtype: float64

# %%
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV      TAXRM
# 0     15.3  396.90   4.98  24.0  45.019011
# 1     17.8  396.90   9.14  21.6  37.688834
# 2     17.8  392.83   4.03  34.7  33.681280
# 3     18.7  394.63   2.94  33.4  31.723350
# 4     18.7  396.90   5.33  36.2  31.061984

# %%
data.plot(kind='scatter',x='MEDV',y='TAXRM' , alpha=0.9)
# plt.show()
# Out:
# <Axes: xlabel='MEDV', ylabel='TAXRM'>

# %%
# Train Test Split
from sklearn.model_selection import train_test_split
train_data,test_data=train_test_split(data,test_size=0.2,random_state=42)
print(f"train data is {train_data.shape} and test data is {test_data.shape}")
# Out:
# train data is (404, 15) and test data is (102, 15)

# %%
housing_features=train_data.drop("MEDV",axis=1)
housing_labels=test_data["MEDV"].copy()

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
pipe=Pipeline([ ('imputer',SimpleImputer(strategy='median'))])

# %%
housing_features=pipe.fit_transform(data)

# %%
from sklearn.tree import DecisionTreeRegressor
model=DecisionTreeRegressor()

# %%
from sklearn.model_selection import  cross_val_score
scores=cross_val_score(model1,housing_features,housing_labels,scoring="neg_mean_squared_error"
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[156], line 7
#       4 housing_features_scaled = scaler.fit_transform(housing_features)
#       6 model = LinearRegression()
# ----> 7 model.fit(housing_features_scaled, housing_labels)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_base.py:648, in LinearRegression.fit(self, X, y, sample_weight)
#     644 n_jobs_ = self.n_jobs
#     646 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 648 X, y = self._validate_data(
#     649     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     650 )
#     652 sample_weight = _check_sample_weight(
#     653     sample_weight, X, dtype=X.dtype, only_non_negative=True
#     654 )
#     656 X, y, X_offset, y_offset, X_scale = _preprocess_data(
#     657     X,
#     658     y,
#    (...)
# ...
