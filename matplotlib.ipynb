# %%
# %matplotlib inline
from matplotlib import pyplot as plt
from matplotlib import style
style.use('ggplot')

# %%
plt.plot([1,2,3],[2,5,7])
plt.show()

# %%
plt.plot([3,5,7],[5,17,9])
plt.title("Usman Graph")
plt.xlabel("Width")
plt.ylabel("Height")
plt.show()

# %%
from matplotlib import style
style.use('ggplot')
x=[1,3,6]
y=[3,6,9]
x1=[2,3,4]
y1=[3,4,17]
plt.title("Usman Graphs")
plt.xlabel("Width")
plt.ylabel("Height")

# Simple Graphs

# plt.plot(x,y ,'g', label="Age of X and Y", linewidth=3)  # if you want to bold line
# plt.plot(x1,y1,'y', label="Age of X1 and Y1")

# Scatter Graphs

# plt.scatter(x,y , label="Age of X and Y", linewidth=3)  # if you want to bold line
# plt.scatter(x1,y1, label="Age of X1 and Y1")

# Histogram Graphs

# plt.hist(x , label="Age of X and Y", linewidth=3)  # if you want to bold line
# plt.hist(y1, label="Age of X1 and Y1")

# Bar Graphs

# plt.bar(x,y , label="Age of X and Y", linewidth=3)  # if you want to bold line
# plt.bar(x1,y1, label="Age of X1 and Y1", color='g')

 # Histogram Graphs
# ages=[22,44,55,66,77,88,99,109]
# bins=[0,10,20,30,41,50,60,70,80]
# plt.hist(ages,bins,histtype='bar' ,label="Age", rwidth=0.8,color='g')  # if you want to bold line


# Stack PLot
# days=[1,2,3,4,5,6,]
# sleep=[7,8,9,2,5,6]
# eat=[2,3,4,7,4,2]
# work=[2,6,3,7,6,4]
# play=[7,9,4,2,4,6]
# plt.plot([],[],color='m',label="sleep",linewidth=5)
# plt.plot([],[],color='c',label="Eat",linewidth=5)
# plt.plot([],[],color='r',label="Work",linewidth=5)
# plt.plot([],[],color='k',label="play",linewidth=5)
# plt.stackplot(days,sleep,eat,work,play,colors=['m','c','r','k'])


# Pie Chart
slices=[10,20,30,40]
activities=['sleep','eat','work','play']
cols=['c','m','r','b']
plt.pie(slices,labels=activities,colors=cols,startangle=90,shadow=True,explode=(0,0.1,0,0),autopct='%1.1f%%')
plt.legend()
# plt.grid(True,color='k')
plt.show()
